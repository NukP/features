# %% [markdown]
# ## Notes

# %%
from features import visualize, features_list

from pathlib import Path
path_excel = Path(r"resources\dataset_7June20225_itteration5_CO2only.xlsx").resolve()

# %%
df_out = visualize.eval_feature_ablation(df_source=r"resources\dataset_7June20225_itteration5_CO2only.xlsx",
                                         drop_features=["Eapp (V)"])
