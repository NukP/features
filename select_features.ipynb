# %%
from features import visualize

# %%
df_out = visualize.eval_feature_ablation(df_source=r"resources\dataset_7June20225_itteration5_CO2only.xlsx",
                                         drop_features=["Eapp (V)"])
# Out:
# n_samples=4704, n_features=56
# Targets to evaluate: ['fe-H2', 'fe-C2H4', 'fe-CH4']
#
# ================================================================================
# TARGET: fe-H2
# ================================================================================
#
# Baseline (10-fold CV) for fe-H2:
#   R²   = 0.9327 ± 0.0090
#   RMSE = 0.082893 ± 0.005158
#
# Features to drop (evaluated in the retrain-without-feature model):
# ['Eapp (V)']
#
# ================================================================================
# TARGET: fe-C2H4
# ================================================================================
#
# Baseline (10-fold CV) for fe-C2H4:
#   R²   = 0.9405 ± 0.0070
#   RMSE = 0.049833 ± 0.003158
#
# Features to drop (evaluated in the retrain-without-feature model):
# ['Eapp (V)']
#
# ================================================================================
# TARGET: fe-CH4
# ================================================================================
#
# Baseline (10-fold CV) for fe-CH4:
#   R²   = 0.8794 ± 0.0171
#   RMSE = 0.043090 ± 0.003238
#
# Features to drop (evaluated in the retrain-without-feature model):
# ['Eapp (V)']
#
# --- Retrain-without-selected-features (rows = product) ---
#          delta_drop_r2_mean delta_r2_significant? delta_rmse_significant?  \
# product
# fe-H2              0.008695                     ❌                       ✅
# fe-C2H4            0.004300                     ❌                       ❌
# fe-CH4             0.009757                     ❌                       ❌
#
#          delta_drop_r2_std  delta_drop_rmse_mean  delta_drop_rmse_std  \
# product
# fe-H2             0.007312             -0.005596             0.005013
# fe-C2H4           0.008632             -0.001851             0.003756
# fe-CH4            0.013071             -0.001771             0.002328
#
#          drop_r2_mean  drop_r2_std  drop_rmse_mean  drop_rmse_std  \
# product
# fe-H2        0.941363     0.008633        0.077296       0.004874
# fe-C2H4      0.944792     0.007382        0.047982       0.003430
# fe-CH4       0.889146     0.011840        0.041320       0.001646
#
#          baseline_r2_mean  baseline_r2_std  baseline_rmse_mean  \
# product
# fe-H2            0.932669         0.009026            0.082893
# fe-C2H4          0.940492         0.007023            0.049833
# fe-CH4           0.879389         0.017105            0.043090
#
#          baseline_rmse_std
# product
# fe-H2             0.005158
# fe-C2H4           0.003158
# fe-CH4            0.003238
